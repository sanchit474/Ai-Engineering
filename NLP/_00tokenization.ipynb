# %%
# go throw nltk documentation and find out about tokenization and how to use it in python

# %%
corpus = """ This is a sample corpus of text that we will use for our analysis. It contains multiple sentences!, and we will be performing various operations on it, let's see"""
print(corpus)

# %%
# Tokenization 
# Sentence to paragraph
import nltk

from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(corpus)
sentences

# %%
for sentence in sentences:
    [print(sentence)]

# %%
# Tokenization 
# Sentence to words
# paragraph to words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)

# %%
from nltk.tokenize import TreebankWordDetokenizer
tokenizer =TreebankWordDetokenizer()
tokenizer.tokenize(corpus)
