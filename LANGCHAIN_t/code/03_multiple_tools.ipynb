# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq"
)

# %%
llm_response = llm.invoke("tell me how i can use multiple tools in langchain")
print(llm_response.content)

# %% [markdown]
# # Multiple Tool Agent
