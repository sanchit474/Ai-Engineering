# %%
import langchain
# langchain.__version__

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
# Out:
# True

# %% [markdown]
# generic LLM using chat_models

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq"
)

# %%
response = model.invoke("write an 10 word essay on AI")
print(response.content)
# Out:
# Artificial intelligence revolutionizes technology and transforms human daily life significantly.

# %% [markdown]
# Streaming

# %%
for chunk in model.stream("write an 1000 word essay on AI"):
    print(chunk.content, end="", flush=True)
# Out:
# **The Rise of Artificial Intelligence: A New Era of Human Innovation**
#
# Artificial Intelligence (AI) has been a topic of fascination and debate for decades, with its roots dating back to the mid-20th century. The concept of creating intelligent machines that can think, learn, and interact like humans has been a longstanding goal of computer scientists, engineers, and researchers. In recent years, AI has made tremendous progress, transforming from a mere idea to a tangible reality that is revolutionizing various aspects of our lives. This essay will explore the evolution of AI, its current applications, and the potential implications of this technology on human society.
#
# **History of Artificial Intelligence**
#
# ...

# %%
print(response.content)
# Out:
# Artificial intelligence revolutionizes technology and transforms human daily life significantly.

# %% [markdown]
# Batch

# %%
responses = model.batch(
    [
    "capital of uttar pradesh",
    "who is the prime minister of india",
    "current cm of uttar pradesh",
    ],
    config={
        'max_concurrency': 2,
    }
)
for response in responses:
    print(response.content)
# Out:
# The capital of Uttar Pradesh is Lucknow.
# The current Prime Minister of India is Narendra Modi. He has been serving as the Prime Minister of India since May 26, 2014, and is currently in his second term, having been re-elected in 2019.
# The current Chief Minister of Uttar Pradesh is Yogi Adityanath. He has been serving as the Chief Minister of Uttar Pradesh since March 19, 2017.

# %% [markdown]
# specif llm using langchain

# %%
from langchain_groq import ChatGroq
# Initialize Qwen model on Groq
# llm = ChatGroq(
#     model="qwen/qwen3-32b",   # Change to any Qwen model available in your Groq account
#     temperature=0
# )

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7,
)

# %%
response = llm.invoke("write a java code for the fibonacci:")
print(response.content)
